# %% [markdown]
# <a href="https://colab.research.google.com/github/Praneetha5151/Pasupuleti_IT533/blob/main/Pasupuleti_IT533.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
amazon = pd.read_csv("https://raw.githubusercontent.com/Praneetha5151/Pasupuleti_IT533/main/amazon_toy_sample_clean.csv",encoding="ISO-8859-1")

# %%
amazon.head(15)
# Out:
#                              uniq_id  \
# 0   dafc6b4ba4b4a3e7b4ff83402a196ae8
# 1   ba85fb9368114fce646379ed12750a5f
# 2   14e24c29ba38c2717754baa2638f242a
# 3   048d64d2ba61c23f6280663a7281ff19
# 4   7b72f597db5d74d35c4f91ef69708cf1
# 5   7b8a04095b5e4984c57fd45eb327feb1
# 6   334f3da31388b329419e9c54b88d9275
# 7   1b57a83b8acc830686f85024b06d3b35
# 8   48a2698da1200c09094a828f5ade41d8
# 9   bacca30f6448922f159a66405890f9bb
# 10  881f857dc055961688264074803fe62f
# 11  7474087a1e54819bf540dbf10dfd797c
# 12  b92917bb1cf7587c7d463c22cc881a70
# 13  de4384d89a29f8534eb3ea6addb5c40c
# 14  5d1f009be30082c703fdd9a29afd1009
#
#                                          product_name  \
# 0                                       Dinosaur Eggs
# 1    Neopets 4 Trading Card Fun Packs (2 Bonus Cards)
# 2           Latex Assorted Water Balloons, Pack of 40
# 3                 iCarly Shopper Bag - Lilac and Pink
# 4   4 Packs of Mini Colouring Pencils (4 pencils i...
# ...

# %% [markdown]
# What is the structure of the dataset? How many columns and rows does it have?

# %%
amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6336 entries, 0 to 6335
# Data columns (total 17 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   uniq_id                                      6336 non-null   object
#  1   product_name                                 6336 non-null   object
#  2   manufacturer                                 6336 non-null   object
#  3   price                                        6336 non-null   float64
#  4   number_available_in_stock                    6336 non-null   int64
#  5   status                                       6336 non-null   object
#  6   number_of_reviews                            6336 non-null   int64
#  7   number_of_answered_questions                 6336 non-null   int64
#  8   average_review_rating_of_5                   6336 non-null   float64
# ...

# %% [markdown]
# What do you think is the class attribute?
#
# I think class attribute is average_review_rating_of_5 attribute because it depends on other attributes.

# %% [markdown]
# Calculate the following for the CLASS ATTRIBUTE in your dataset: The 5-number summary and the standard deviation. If your class attribute is categorical, be ready to calculate a 5 number summary and standard deviation for the next best numeric attribute.

# %%
amazon.average_review_rating_of_5.describe()
# Out:
# count    6336.000000
# mean        4.686222
# std         0.427656
# min         0.000000
# 25%         4.500000
# 50%         4.900000
# 75%         5.000000
# max         5.000000
# Name: average_review_rating_of_5, dtype: float64

# %% [markdown]
# For the class attribute, build a boxplot.

# %%
x = amazon[('status')]
y = amazon[('average_review_rating_of_5')]
plt.scatter(x, y)
plt.show()

# %% [markdown]
# For each of the two numeric attributes you have identified, calculate the 5-number summary and the standard deviation.

# %%
import statistics
amazon.number_of_reviews.describe()
# Out:
# count    6336.000000
# mean       11.220013
# std        39.292836
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         8.000000
# max      1399.000000
# Name: number_of_reviews, dtype: float64

# %%
amazon.number_of_answered_questions.describe()
# Out:
# count    6336.000000
# mean        3.927715
# std        13.417801
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max       523.000000
# Name: number_of_answered_questions, dtype: float64

# %% [markdown]
# For each of the two numeric attributes you have identified, calculate the Euclidian Distance to the CLASS ATTRIBUTE.

# %%
p1 = np.array(amazon.number_of_answered_questions)
p2 = np.array(amazon.average_review_rating_of_5)
d = np.linalg.norm(p2 - p1)
print("The distance between number_of_answered_questions and average_review_rating_of_5 is ", d)
# Out:
# The distance between number_of_answered_questions and average_review_rating_of_5 is  1070.1381359432064

# %%
p1 = np.array(amazon.number_of_reviews)
p2 = np.array(amazon.average_review_rating_of_5)
d = np.linalg.norm(p2 - p1)
print("The distance between number_of_answered_questions and average_review_rating_of_5 is ", d)
# Out:
# The distance between number_of_answered_questions and average_review_rating_of_5 is  3173.5915033286815

# %% [markdown]
# INTERPRET YOUR RESULTS: What does the output to each of the questions above tell you about each attribute you have looked at AND about the distance between each of the two numeric attributes and the class attribute. FOR WHAT  PURPOSE OR ACTION could your results be useful?
#
# From the all above outputs I learn what attributes present in a dataset.
